# %% [markdown]
# # Day-8 (15-06-21) Task's
# Create a function for finding the leap years in the given range#

# %%
def leap_year(x):
    if (x%4==0 and x%100!=0 or x%400==0):
        return True
    else:
        return False
start = int(input("Enter the starting year: "))
end = int(input("Enter the ending year: "))
print("Leap years between the range", start, "and", end, "are")
for i in range(start, end):
    if leap_year(i) == True:
        print(i)
# Out:
# Enter the starting year: 2002
# Enter the ending year: 2512
# Leap years between the range 2002 and 2512 are
# 2004
# 2008
# 2012
# 2016
# 2020
# 2024
# 2028
# 2032
# 2036
# 2040
# 2044
# 2048
# 2052
# 2056
# 2060
# 2064
# 2068
# 2072
# 2076
# 2080
# 2084
# 2088
# 2092
# 2096
# 2104
# 2108
# 2112
# 2116
# 2120
# 2124
# 2128
# 2132
# 2136
# 2140
# 2144
# 2148
# 2152
# 2156
# 2160
# 2164
# 2168
# 2172
# 2176
# 2180
# 2184
# 2188
# 2192
# 2196
# 2204
# 2208
# 2212
# 2216
# 2220
# 2224
# 2228
# 2232
# 2236
# 2240
# 2244
# 2248
# 2252
# 2256
# 2260
# 2264
# 2268
# 2272
# 2276
# 2280
# 2284
# 2288
# 2292
# 2296
# 2304
# 2308
# 2312
# 2316
# 2320
# 2324
# 2328
# 2332
# 2336
# 2340
# 2344
# 2348
# 2352
# 2356
# 2360
# 2364
# 2368
# 2372
# 2376
# 2380
# 2384
# 2388
# 2392
# 2396
# 2400
# 2404
# 2408
# 2412
# 2416
# 2420
# 2424
# 2428
# 2432
# 2436
# 2440
# 2444
# 2448
# 2452
# 2456
# 2460
# 2464
# 2468
# 2472
# 2476
# 2480
# 2484
# 2488
# 2492
# 2496
# 2504
# 2508

# %%
def armstrong(x, y):
    for i in range(x, y+1):
        num = i
        result = 0
        n = len(str(i))
        while(i != 0):
            digit = i % 10
            result = result + digit ** n
            i = i//10
        if num == result:
            print(num)
initial = int(input("Enter the start number: "))
final = int(input("Enter the final number: "))
print("The Armstrong numbers from", initial, "to", final, "are")
armstrong(initial, final)
# Out:
# Enter the start number: 9
# Enter the final number: 420
# The Armstrong numbers from 9 to 420 are
# 9
# 153
# 370
# 371
# 407

# %%
def prime_number(x1, x2):
    for number in range(x1, x2+1):
        for i in range(2, number):
            if number%i == 0:
                break
        else:
            print(number)
    
start = int(input("Enter the start number: "))
end = int(input("Enter the end number: "))
print("Prime numbers between", start, "and", end, "are")
prime_number(start,end)
# Out:
# Enter the start number: 10
# Enter the end number: 40
# Prime numbers between 10 and 40 are
# 11
# 13
# 17
# 19
# 23
# 29
# 31
# 37

# %%
def count(string):
    count_str = 0
    for i in string:
        count_str = count_str + 1
    return count_str 
inp = input("Enter a string: ")
print("Count of elements in the string is:",count(inp))
# Out:
# Enter a string: hello world
# Count of elements in the string is: 11
